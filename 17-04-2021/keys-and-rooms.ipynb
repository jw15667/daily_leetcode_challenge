# %% [markdown]
# # Keys and Rooms

# %% [markdown]
# https://leetcode.com/problems/keys-and-rooms/

# %%
rooms = [[4],[3],[],[2,5,7],[1],[],[8,9],[],[],[6]]

# %%
# for i in range(len(rooms[::-1])-1):
#     x=len(rooms)-i-1
#     print(x)
#     local_list = rooms.copy()
#     local_list.remove(rooms[x])
#     print(local_list)
#     found = any(x in num for num in local_list)
#     print(found)
# #     if found == False:
# #         print(found)

# %%
x = True
i = 0
while x == True:
    y = rooms[i]
    if y is 
    z = room[y]
#     if i not found:
#         x = False
# Out:
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# [4]
# ...

# %%
keys_to_rooms = {0}
room = [0]
for r in room:
    for key in rooms[r]:
        room += [key] if key not in keys_to_rooms else []
        keys_to_rooms |= {key}
print(len(keys_to_rooms) == len(rooms))
# Out:
# False

# %%
local_dict
# Out:
# {0: [1, 3], 1: [3, 0, 1], 2: [2], 3: [0]}
